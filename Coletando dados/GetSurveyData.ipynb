# %% [markdown]
# After completing the survey using google forms:
# - Publish your spreadsheet with the answers
# - You need to publish it as a CSV file.
# - Copy and paste the link below.

# %%
LinkToData_asCSV="https://docs.google.com/spreadsheets/d/e/2PACX-1vS4oxsRxGyF17HbRJ3_WFX1Pj4A0rgugutC1YQfXV42D6kCRivonxct5gQxdJ-2leeK7kN0SwHkbDUY/pub?gid=1920066012&single=true&output=csv"

# %% [markdown]
# Once you have the link, it is really easy to get the data:

# %%
import pandas as pd

data_answers=pd.read_csv(LinkToData_asCSV)

# %%
data_answers
# Out:
#          Marca temporal      First Name             Surname  Age     Sex  \
# 0   11/08/2022 13:22:48  Victor Gabriel           Alcantara   24    Male
# 1   11/08/2022 13:22:52          André              Martins   20    Male
# 2   11/08/2022 13:23:25           Julia              Cabral   28  Female
# 3   11/08/2022 13:23:39          Elias           Rodrigues    39    Male
# 4   11/08/2022 13:23:54         Jessica               Luzes   37  Female
# 5   11/08/2022 13:24:12          Daniel        Bonatto Seco   28    Male
# 6   11/08/2022 13:24:22         Gabriel               Doria   22    Male
# 7   11/08/2022 13:24:26        Graziela     Dumard da Silva   31  Female
# 8   11/08/2022 13:24:50         Izabela              Borges   27  Female
# 9   11/08/2022 13:25:50          Thiago           Fernandes   38    Male
# 10  11/08/2022 13:26:50         Miguel   Domingos de Barros   24    Male
#
#    Experience in R? Experience in Python?
# 0      Skilled user                  None
# 1              None                  None
# 2      Skilled user                  None
# 3              None                  Some
# 4              Some                  None
# 5              Some                  Fair
# 6              Some                  None
# 7              None                  None
# 8              Some                  Some
# 9              None                  Some
# 10             None                  Some
